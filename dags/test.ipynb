# %%
from googleapiclient.discovery import build
from dateutil import parser
import pandas as pd
from IPython.display import JSON

# Data viz packages
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# NLP
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hafss\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hafss\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Importing the functions from your other files
from preprocessing import preprocess_video_data
from data_analysis import analyze_video_performance
from scrapping import get_channel_stats, get_video_details, get_comments_in_videos  # Assuming these are already implemented

api_key = 'AIzaSyAxs7uzwcGOqJftvR_p9gqZ2nT6KmwtKj4'
channel_ids = ['UCoOae5nYA7VqaXzerajD0lg']  # Example channel IDs
playlistId = "UUoOae5nYA7VqaXzerajD0lg"

# %%
# main.py

from googleapiclient.discovery import build
from scrapping import (
    get_channel_stats,
    get_video_ids,
    get_video_details,
    get_comments_in_videos,
    save_scraped_data
)
import pandas as pd

def main():
    # Your YouTube Data API key
    api_key = 'AIzaSyAxs7uzwcGOqJftvR_p9gqZ2nT6KmwtKj4'  # Replace with your actual API key

    # Channel and playlist IDs
    channel_ids = ['UCoOae5nYA7VqaXzerajD0lg']  # Example channel IDs
    playlist_id = "UUoOae5nYA7VqaXzerajD0lg"    # Example playlist ID (uploads playlist)

    # Initialize YouTube API client
    youtube = build('youtube', 'v3', developerKey=api_key)

    # 1. Get Channel Statistics
    try:
        print("Fetching channel statistics...")
        channel_stats = get_channel_stats(youtube, channel_ids)
        print("Channel Statistics Retrieved:")
        print(channel_stats)
    except Exception as e:
        print(f"Error fetching channel statistics: {e}")
        return

    # 2. Get Video IDs from Playlist
    try:
        print("\nFetching video IDs from playlist...")
        video_ids = get_video_ids(youtube, playlist_id)
        print(f"Total videos retrieved: {len(video_ids)}")
        print(f"First 5 Video IDs: {video_ids[:5]}")
    except Exception as e:
        print(f"Error fetching video IDs: {e}")
        return

    # 3. Get Video Details
    try:
        print("\nFetching video details...")
        video_details = get_video_details(youtube, video_ids)
        print("Video Details Retrieved:")
        print(video_details.head())
    except Exception as e:
        print(f"Error fetching video details: {e}")
        return

    # 4. Get Comments from Videos
    try:
        print("\nFetching comments from videos...")
        comments = get_comments_in_videos(youtube, video_ids)
        print("Comments Retrieved:")
        print(comments.head())
    except Exception as e:
        print(f"Error fetching comments: {e}")
        return

    # 5. Save Scraped Data to CSV Files
    try:
        print("\nSaving scraped data to CSV files...")
        save_scraped_data(channel_stats, "channel_stats")
        save_scraped_data(video_details, "video_details")
        save_scraped_data(comments, "comments")
        print("Data successfully saved to CSV files.")
    except Exception as e:
        print(f"Error saving data: {e}")
        return

if __name__ == "__main__":
    main()
# Out:
# Fetching channel statistics...
# Channel Statistics Retrieved:
#   channelName subscribers      views totalVideos                playlistId
# 0  Ali Abdaal     6020000  466548749        1054  UUoOae5nYA7VqaXzerajD0lg
#
# Fetching video IDs from playlist...
# Total videos retrieved: 1051
# First 5 Video IDs: ['W2afI0n8pUk', 'gP-C_utcBdY', 'vuKFwdJF5wU', 'avih_knbVjA', '0mE919RsXOc']
#
# Fetching video details...
# Video Details Retrieved:
#       video_id channelTitle  \
# 0  W2afI0n8pUk   Ali Abdaal
# 1  gP-C_utcBdY   Ali Abdaal
# 2  vuKFwdJF5wU   Ali Abdaal
# 3  avih_knbVjA   Ali Abdaal
# 4  0mE919RsXOc   Ali Abdaal
#
#                                                title  \
# 0           6 Habits to Make 2025 Your Best Year Yet
# 1                        This will change your life!
# 2            Intrinsic vs. Instrumental Motivation 🚀
# 3                                          Wanting 🍎
# 4  The delicate balance between having enough and...
#
# ...

# %%
# main.py

from googleapiclient.discovery import build
from scrapping import (
    get_channel_stats,
    get_video_ids,
    get_video_details,
    get_comments_in_videos,
    save_scraped_data
)
from preprocessing import preprocess_video_data
import pandas as pd
import os

def main():
    # Your YouTube Data API key
    api_key = 'YOUR_API_KEY_HERE'  # Replace with your actual API key

    # Channel and playlist IDs
    channel_ids = ['UCoOae5nYA7VqaXzerajD0lg']  # Example channel IDs
    playlist_id = "UUoOae5nYA7VqaXzerajD0lg"    # Example playlist ID (uploads playlist)

    # Initialize YouTube API client
    youtube = build('youtube', 'v3', developerKey=api_key)

    # 1. Get Channel Statistics
    try:
        print("Fetching channel statistics...")
        channel_stats = get_channel_stats(youtube, channel_ids)
        print("Channel Statistics Retrieved:")
        print(channel_stats)
    except Exception as e:
        print(f"Error fetching channel statistics: {e}")
        return

    # 2. Get Video IDs from Playlist
    try:
        print("\nFetching video IDs from playlist...")
        video_ids = get_video_ids(youtube, playlist_id)
        print(f"Total videos retrieved: {len(video_ids)}")
        print(f"First 5 Video IDs: {video_ids[:5]}")
    except Exception as e:
        print(f"Error fetching video IDs: {e}")
        return

    # 3. Get Video Details
    try:
        print("\nFetching video details...")
        video_details = get_video_details(youtube, video_ids)
        print("Video Details Retrieved:")
        print(video_details.head())
    except Exception as e:
        print(f"Error fetching video details: {e}")
        return

    # 4. Preprocess Video Details
    try:
        print("\nPreprocessing video details...")
        preprocessed_video_details = preprocess_video_data(video_details)
        print("Preprocessed Video Details:")
        print(preprocessed_video_details.head())
    except Exception as e:
        print(f"Error preprocessing video details: {e}")
        return

    # 5. Get Comments from Videos
    try:
        print("\nFetching comments from videos...")
        comments = get_comments_in_videos(youtube, video_ids)
        print("Comments Retrieved:")
        print(comments.head())
    except Exception as e:
        print(f"Error fetching comments: {e}")
        return

    # 6. Save Scraped Data to CSV Files
    try:
        print("\nSaving scraped data to CSV files...")
        save_scraped_data(channel_stats, "channel_stats")
        save_scraped_data(video_details, "video_details_raw")            # Raw video details
        save_scraped_data(preprocessed_video_details, "video_details")   # Preprocessed video details
        save_scraped_data(comments, "comments")
        print("Data successfully saved to CSV files.")
    except Exception as e:
        print(f"Error saving data: {e}")
        return

if __name__ == "__main__":
    main()
# Out:
# Fetching channel statistics...
# Error fetching channel statistics: <HttpError 400 when requesting https://youtube.googleapis.com/youtube/v3/channels?part=snippet%2CcontentDetails%2Cstatistics&id=UCoOae5nYA7VqaXzerajD0lg&key=YOUR_API_KEY_HERE&alt=json returned "API key not valid. Please pass a valid API key.". Details: "[{'message': 'API key not valid. Please pass a valid API key.', 'domain': 'global', 'reason': 'badRequest'}]">

# %%
# main.py

from googleapiclient.discovery import build
from scrapping import (
    get_channel_stats,
    get_video_ids,
    get_video_details,
    get_comments_in_videos,
    save_scraped_data
)
from preprocessing import preprocess_video_data
import pandas as pd
import os

def main():
    # Your YouTube Data API key
    api_key = 'AIzaSyAxs7uzwcGOqJftvR_p9gqZ2nT6KmwtKj4'  # Replace with your actual API key

    # Channel and playlist IDs
    channel_ids = ['UCoOae5nYA7VqaXzerajD0lg']  # Example channel IDs
    playlist_id = "UUoOae5nYA7VqaXzerajD0lg"    # Example playlist ID (uploads playlist)

    # Initialize YouTube API client
    youtube = build('youtube', 'v3', developerKey=api_key)

    # 1. Get Channel Statistics
    try:
        print("Fetching channel statistics...")
        channel_stats = get_channel_stats(youtube, channel_ids)
        print("Channel Statistics Retrieved:")
        print(channel_stats)
    except Exception as e:
        print(f"Error fetching channel statistics: {e}")
        return

    # 2. Get Video IDs from Playlist
    try:
        print("\nFetching video IDs from playlist...")
        video_ids = get_video_ids(youtube, playlist_id)
        print(f"Total videos retrieved: {len(video_ids)}")
        print(f"First 5 Video IDs: {video_ids[:5]}")
    except Exception as e:
        print(f"Error fetching video IDs: {e}")
        return

    # 3. Get Video Details
    try:
        print("\nFetching video details...")
        video_details = get_video_details(youtube, video_ids)
        print("Video Details Retrieved:")
        print(video_details.head())
    except Exception as e:
        print(f"Error fetching video details: {e}")
        return

    # 4. Preprocess Video Details
    try:
        print("\nPreprocessing video details...")
        preprocessed_video_details = preprocess_video_data(video_details)
        print("Preprocessed Video Details:")
        print(preprocessed_video_details.head())
    except Exception as e:
        print(f"Error preprocessing video details: {e}")
        return

    # 5. Get Comments from Videos
    try:
        print("\nFetching comments from videos...")
        comments = get_comments_in_videos(youtube, video_ids)
        print("Comments Retrieved:")
        print(comments.head())
    except Exception as e:
        print(f"Error fetching comments: {e}")
        return

    # 6. Save Scraped Data to CSV Files
    try:
        print("\nSaving scraped data to CSV files...")
        save_scraped_data(channel_stats, "channel_stats")
        save_scraped_data(video_details, "video_details_raw")            # Raw video details
        save_scraped_data(preprocessed_video_details, "video_details")   # Preprocessed video details
        save_scraped_data(comments, "comments")
        print("Data successfully saved to CSV files.")
    except Exception as e:
        print(f"Error saving data: {e}")
        return

if __name__ == "__main__":
    main()
# Out:
# Fetching channel statistics...
# Channel Statistics Retrieved:
#   channelName subscribers      views totalVideos                playlistId
# 0  Ali Abdaal     6020000  466548749        1054  UUoOae5nYA7VqaXzerajD0lg
#
# Fetching video IDs from playlist...
# Total videos retrieved: 1051
# First 5 Video IDs: ['W2afI0n8pUk', 'gP-C_utcBdY', 'vuKFwdJF5wU', 'avih_knbVjA', '0mE919RsXOc']
#
# Fetching video details...
# Video Details Retrieved:
#       video_id channelTitle  \
# 0  W2afI0n8pUk   Ali Abdaal
# 1  gP-C_utcBdY   Ali Abdaal
# 2  vuKFwdJF5wU   Ali Abdaal
# 3  avih_knbVjA   Ali Abdaal
# 4  0mE919RsXOc   Ali Abdaal
#
#                                                title  \
# 0           6 Habits to Make 2025 Your Best Year Yet
# 1                        This will change your life!
# 2            Intrinsic vs. Instrumental Motivation 🚀
# 3                                          Wanting 🍎
# 4  The delicate balance between having enough and...
#
# ...

# %%
# main.py

from googleapiclient.discovery import build
from scrapping import (
    get_channel_stats,
    get_video_ids,
    get_video_details,
    get_comments_in_videos,
    save_scraped_data
)
from preprocessing import preprocess_video_data
from data_analysis import analyze_video_performance
import pandas as pd
import os

def main():
    # Your YouTube Data API key
    api_key = 'AIzaSyAxs7uzwcGOqJftvR_p9gqZ2nT6KmwtKj4'  # Replace with your actual API key

    # Channel and playlist IDs
    channel_ids = ['UCoOae5nYA7VqaXzerajD0lg']  # Example channel IDs
    playlist_id = "UUoOae5nYA7VqaXzerajD0lg"    # Example playlist ID (uploads playlist)

    # Initialize YouTube API client
    youtube = build('youtube', 'v3', developerKey=api_key)

    # 1. Get Channel Statistics
    try:
        print("Fetching channel statistics...")
        channel_stats = get_channel_stats(youtube, channel_ids)
        print("Channel Statistics Retrieved:")
        print(channel_stats)
    except Exception as e:
        print(f"Error fetching channel statistics: {e}")
        return

    # 2. Get Video IDs from Playlist
    try:
        print("\nFetching video IDs from playlist...")
        video_ids = get_video_ids(youtube, playlist_id)
        print(f"Total videos retrieved: {len(video_ids)}")
        print(f"First 5 Video IDs: {video_ids[:5]}")
    except Exception as e:
        print(f"Error fetching video IDs: {e}")
        return

    # 3. Get Video Details
    try:
        print("\nFetching video details...")
        video_details = get_video_details(youtube, video_ids)
        print("Video Details Retrieved:")
        print(video_details.head())
    except Exception as e:
        print(f"Error fetching video details: {e}")
        return

    # 4. Preprocess Video Details
    try:
        print("\nPreprocessing video details...")
        preprocessed_video_details = preprocess_video_data(video_details)
        print("Preprocessed Video Details:")
        print(preprocessed_video_details.head())
    except Exception as e:
        print(f"Error preprocessing video details: {e}")
        return

    # 5. Get Comments from Videos
    try:
        print("\nFetching comments from videos...")
        comments = get_comments_in_videos(youtube, video_ids)
        print("Comments Retrieved:")
        print(comments.head())
    except Exception as e:
        print(f"Error fetching comments: {e}")
        return

    # 6. Save Scraped Data to CSV Files
    try:
        print("\nSaving scraped data to CSV files...")
        save_scraped_data(channel_stats, "channel_stats")
        save_scraped_data(video_details, "video_details_raw")            # Raw video details
        save_scraped_data(preprocessed_video_details, "video_details")   # Preprocessed video details
        save_scraped_data(comments, "comments")
        print("Data successfully saved to CSV files.")
    except Exception as e:
        print(f"Error saving data: {e}")
        return

    # 7. Analyze Video Performance
    try:
        print("\nAnalyzing video performance...")
        analyze_video_performance(preprocessed_video_details)
        print("Video performance analysis completed. Plots have been saved.")
    except Exception as e:
        print(f"Error analyzing video performance: {e}")
        return

if __name__ == "__main__":
    main()
# Out:
# Fetching channel statistics...
# Channel Statistics Retrieved:
#   channelName subscribers      views totalVideos                playlistId
# 0  Ali Abdaal     6020000  466548749        1054  UUoOae5nYA7VqaXzerajD0lg
#
# Fetching video IDs from playlist...
# Total videos retrieved: 1051
# First 5 Video IDs: ['W2afI0n8pUk', 'gP-C_utcBdY', 'vuKFwdJF5wU', 'avih_knbVjA', '0mE919RsXOc']
#
# Fetching video details...
# Video Details Retrieved:
#       video_id channelTitle  \
# 0  W2afI0n8pUk   Ali Abdaal
# 1  gP-C_utcBdY   Ali Abdaal
# 2  vuKFwdJF5wU   Ali Abdaal
# 3  avih_knbVjA   Ali Abdaal
# 4  0mE919RsXOc   Ali Abdaal
#
#                                                title  \
# 0           6 Habits to Make 2025 Your Best Year Yet
# 1                        This will change your life!
# 2            Intrinsic vs. Instrumental Motivation 🚀
# 3                                          Wanting 🍎
# 4  The delicate balance between having enough and...
#
# ...
